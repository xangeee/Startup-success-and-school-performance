# %%
# !pip install duckdb==0.5.1
import duckdb
import pandas as pd
import numpy as np
from datetime import datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting duckdb==0.5.1
#   Downloading duckdb-0.5.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.8/dist-packages (from duckdb==0.5.1) (1.21.6)
# Installing collected packages: duckdb
# Successfully installed duckdb-0.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')

#from google.colab import drive
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
conn = duckdb.connect("/content/drive/MyDrive/ADSDB BASES DE DATOS/copy_DB_FeatureGeneration", read_only=False)
existingTables = conn.execute("SHOW TABLES").fetchall()
existingTables
query = "SELECT * from startups_studentsPerformance"
df = conn.execute(query).fetchdf()
df
# Out:
#                            permalink             name  \
# 0                 /organization/x2tv             X2TV
# 1              /organization/xactium          Xactium
# 2          /organization/xactly-corp      Xactly Corp
# 3                  /organization/xad              xAd
# 4              /organization/xagenic          Xagenic
# ...                              ...              ...
# 34098   /organization/x-scan-imaging   X-Scan Imaging
# 34099             /organization/x-ai             x.ai
# 34100  /organization/x1-technologies  X1 Technologies
# 34101    /organization/x2-biosystems    X2 Biosystems
# 34102         /organization/x2impact         X2IMPACT
#
#                     homepage_url  \
# 0                   http://x2.tv
# 1         http://www.xactium.com
# 2      http://www.xactlycorp.com
# 3             http://www.xAd.com
# 4         http://www.xagenic.com
# ...                          ...
# 34098   http://x-scanimaging.com
# 34099                http://x.ai
# 34100          http://www.x1.com
# 34101    http://x2biosystems.com
# 34102    http://www.xplusone.net
#
#                                            category_list  \
# 0                                               |Mobile|
# 1                                  |Enterprise Software|
# 2                                 |Incentives|Analytics|
# 3      |Technology|Apps|Wireless|Search|Local|Mobile|...
# 4                                        |Biotechnology|
# ...                                                  ...
# 34098                              |Hardware + Software|
# 34099                                              |B2B|
# 34100                              |Enterprise Software|
# 34101                                      |Health Care|
# 34102                                      |Health Care|
#
#                      market   funding_total_usd      status country_code  \
# 0                    Mobile           45,00,000   operating          ITA
# 1       Enterprise Software            3,49,000   operating          GBR
# 2                 Analytics         7,38,70,000   operating          USA
# 3                  Wireless         7,40,00,000   operating          USA
# 4             Biotechnology         3,55,00,000   operating          CAN
# ...                      ...                 ...        ...          ...
# 34098   Hardware + Software            6,00,000   operating          USA
# 34099                   B2B           21,00,000   operating          USA
# 34100   Enterprise Software         1,22,00,000   operating          USA
# 34101           Health Care         1,80,23,021   operating          USA
# 34102           Health Care           45,70,000      closed          USA
#
#       state_code         region  ... econ_disadvantaged_math_test_valid  \
# 0            NaN           Rome  ...                             3365.0
# 1            NaN      Sheffield  ...                             2304.0
# 2             MA         Boston  ...                             1935.0
# 3             NY  New York City  ...                            39237.0
# 4             ON        Toronto  ...                              437.0
# ...          ...            ...  ...                                ...
# 34098         CA    SF Bay Area  ...                            23885.0
# 34099         NY  New York City  ...                            39237.0
# 34100         CA    Los Angeles  ...                             8995.0
# 34101         WA        Seattle  ...                            16771.0
# 34102         WA        Seattle  ...                            16771.0
#
#        foster_care_read_test_valid foster_care_math_test_valid  \
# 0                             34.0                        36.0
# 1                             12.0                        12.0
# 2                             27.0                        31.0
# 3                            450.0                       448.0
# 4                              0.0                         0.0
# ...                            ...                         ...
# 34098                        179.0                       184.0
# 34099                        450.0                       448.0
# 34100                         76.0                        71.0
# 34101                        156.0                       148.0
# 34102                        156.0                       148.0
#
#       military_connected_read_test_valid military_connected_math_test_valid  \
# 0                                  364.0                              368.0
# 1                                   20.0                               23.0
# 2                                   28.0                               28.0
# 3                                 1178.0                             1163.0
# 4                                   14.0                               14.0
# ...                                  ...                                ...
# 34098                              386.0                              384.0
# 34099                             1178.0                             1163.0
# 34100                               72.0                               72.0
# 34101                              365.0                              356.0
# 34102                              365.0                              356.0
#
#        population nTeachers enrollment  nPublicSchools  nSchools
# 0         14202.0     905.0    13297.0            22.0        22
# 1          2317.0     185.0     2132.0             9.0         9
# 2          7410.0     555.0     6855.0            14.0        14
# 3        150103.0   10215.0   139888.0           272.0       279
# 4          1182.0      63.0     1119.0             4.0         4
# ...           ...       ...        ...             ...       ...
# 34098    115035.0    4885.0   110150.0           162.0       164
# 34099    150103.0   10215.0   139888.0           272.0       279
# 34100     52009.0    3010.0    48999.0            68.0        70
# 34101     60195.0    3330.0    56865.0           108.0       111
# 34102     60195.0    3330.0    56865.0           108.0       111
#
# [34103 rows x 88 columns]

# %%
#remove columns with duplicated values in columns
df = df[df.iloc[:,1]!= df.iloc[:,2]]
df.head()
# Out:
#                    permalink         name               homepage_url  \
# 0         /organization/x2tv         X2TV               http://x2.tv
# 1      /organization/xactium      Xactium     http://www.xactium.com
# 2  /organization/xactly-corp  Xactly Corp  http://www.xactlycorp.com
# 3          /organization/xad          xAd         http://www.xAd.com
# 4      /organization/xagenic      Xagenic     http://www.xagenic.com
#
#                                        category_list                market   \
# 0                                           |Mobile|                Mobile
# 1                              |Enterprise Software|   Enterprise Software
# 2                             |Incentives|Analytics|             Analytics
# 3  |Technology|Apps|Wireless|Search|Local|Mobile|...              Wireless
# 4                                    |Biotechnology|         Biotechnology
#
#    funding_total_usd      status country_code state_code         region  ...  \
# 0          45,00,000   operating          ITA        NaN           Rome  ...
# 1           3,49,000   operating          GBR        NaN      Sheffield  ...
# 2        7,38,70,000   operating          USA         MA         Boston  ...
# 3        7,40,00,000   operating          USA         NY  New York City  ...
# 4        3,55,00,000   operating          CAN         ON        Toronto  ...
#
#   econ_disadvantaged_math_test_valid  foster_care_read_test_valid  \
# 0                             3365.0                         34.0
# 1                             2304.0                         12.0
# 2                             1935.0                         27.0
# 3                            39237.0                        450.0
# 4                              437.0                          0.0
#
#   foster_care_math_test_valid military_connected_read_test_valid  \
# 0                        36.0                              364.0
# 1                        12.0                               20.0
# 2                        31.0                               28.0
# 3                       448.0                             1178.0
# 4                         0.0                               14.0
#
#   military_connected_math_test_valid  population nTeachers enrollment  \
# 0                              368.0     14202.0     905.0    13297.0
# 1                               23.0      2317.0     185.0     2132.0
# 2                               28.0      7410.0     555.0     6855.0
# 3                             1163.0    150103.0   10215.0   139888.0
# 4                               14.0      1182.0      63.0     1119.0
#
#    nPublicSchools  nSchools
# 0            22.0        22
# 1             9.0         9
# 2            14.0        14
# 3           272.0       279
# 4             4.0         4
#
# [5 rows x 88 columns]

# %%
df = df.apply(pd.to_numeric, errors='ignore')
df.dtypes
# Out:
# permalink          object
# name               object
# homepage_url       object
# category_list      object
#  market            object
#                    ...
# population        float64
# nTeachers         float64
# enrollment        float64
# nPublicSchools    float64
# nSchools            int32
# Length: 88, dtype: object

# %% [markdown]
# # Target column

# %%
df.describe()
df.status.value_counts()
# Out:
# operating    28461
# acquired      3086
# closed        1762
# Name: status, dtype: int64

# %% [markdown]
# # Imputation

# %%
# df.info()

# %%
cols = df.columns
num_cols = df._get_numeric_data().columns
cat_cols = list(set(cols) - set(num_cols))

# %%
# import missingno as msno
# msno.bar(df)

# %%
# msno.heatmap(df)

# %% [markdown]
# The value is 1. This means that there is a perfect correspondence between missing values in feature A and missing values in feature B. You can also see this from the matrix plot you made before.
#
# The values in the heatmap range between -1 and 1. A value of -1 indicates a negative correspondence: A missing value in feature A implies that there is not a missing value in feature B.
#
# Finally, a value of 0 indicates that there is no obvious correspondence between missing values in feature A and missing values in feature B. This is (more or less) the case for all the remaining features.

# %%
df[cat_cols] = df[cat_cols].fillna("Unknown")

# %%
from sklearn.impute import KNNImputer
import numpy as np
# nan = np.nan
imputer = KNNImputer(n_neighbors=5, weights="uniform")
df[num_cols] = imputer.fit_transform(df[num_cols])

# %%
# msno.bar(df)

# %% [markdown]
# # Normalization

# %%
from sklearn import preprocessing
import pandas as pd
d = preprocessing.normalize(df[num_cols])
df[num_cols] = d
df.head()
# Out:
#                    permalink         name               homepage_url  \
# 0         /organization/x2tv         X2TV               http://x2.tv
# 1      /organization/xactium      Xactium     http://www.xactium.com
# 2  /organization/xactly-corp  Xactly Corp  http://www.xactlycorp.com
# 3          /organization/xad          xAd         http://www.xAd.com
# 4      /organization/xagenic      Xagenic     http://www.xagenic.com
#
#                                        category_list                market   \
# 0                                           |Mobile|                Mobile
# 1                              |Enterprise Software|   Enterprise Software
# 2                             |Incentives|Analytics|             Analytics
# 3  |Technology|Apps|Wireless|Search|Local|Mobile|...              Wireless
# 4                                    |Biotechnology|         Biotechnology
#
#    funding_total_usd      status country_code state_code         region  ...  \
# 0          45,00,000   operating          ITA    Unknown           Rome  ...
# 1           3,49,000   operating          GBR    Unknown      Sheffield  ...
# 2        7,38,70,000   operating          USA         MA         Boston  ...
# 3        7,40,00,000   operating          USA         NY  New York City  ...
# 4        3,55,00,000   operating          CAN         ON        Toronto  ...
#
#   econ_disadvantaged_math_test_valid  foster_care_read_test_valid  \
# 0                       3.350891e-10                 3.385744e-12
# 1                       8.825437e-10                 4.596582e-12
# 2                       2.550434e-10                 3.558746e-12
# 3                       3.349353e-10                 3.841295e-12
# 4                       2.590995e-10                 0.000000e+00
#
#   foster_care_math_test_valid military_connected_read_test_valid  \
# 0                3.584906e-12                       3.624738e-11
# 1                4.596582e-12                       7.660969e-12
# 2                4.085967e-12                       3.690551e-12
# 3                3.824222e-12                       1.005566e-11
# 4                0.000000e+00                       8.300670e-12
#
#   military_connected_math_test_valid    population     nTeachers  \
# 0                       3.664570e-11  1.414245e-09  9.012054e-11
# 1                       8.810115e-12  8.875233e-10  7.086397e-11
# 2                       3.690551e-12  9.766779e-10  7.315199e-11
# 3                       9.927613e-12  1.281311e-09  8.719739e-11
# 4                       8.300670e-12  7.008137e-10  3.735301e-11
#
#      enrollment  nPublicSchools      nSchools
# 0  1.324125e-09    2.190776e-12  2.190776e-12
# 1  8.166593e-10    3.447436e-12  3.447436e-12
# 2  9.035260e-10    1.845275e-12  1.845275e-12
# 3  1.194113e-09    2.321849e-12  2.381603e-12
# 4  6.634607e-10    2.371620e-12  2.371620e-12
#
# [5 rows x 88 columns]

# %% [markdown]
# *texto en cursiva*# Balance data

# %%
df.status.value_counts()
import numpy as np
df_op = df[df.status == "operating"]

df_op4 = df_op.sample(n=4000)
aux = set(df_op.index) - set(df_op4.index)
df = df.drop(aux)
df.status.value_counts()
df = df[df.status != "Unknown"]

X = df.loc[:, df.columns != "status"]
Y = df.loc[:, df.columns == "status"]

# %%
# #UNDERSAMPLING
# from imblearn.under_sampling import RandomUnderSampler
# under_sampler = RandomUnderSampler(random_state=42)
# X, Y = under_sampler.fit_resample(X, Y)
# Y.value_counts()

#OVERSAMPLING
from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=42)
X, Y = over_sampler.fit_resample(X, Y)
Y.value_counts()
# Out:
# status
# acquired     4000
# closed       4000
# operating    4000
# dtype: int64

# %%
df = X
df['status'] = Y
df.status.value_counts()
# Out:
# operating    4000
# closed       4000
# acquired     4000
# Name: status, dtype: int64

# %%
#numeric columns
df[num_cols].describe()
# Out:
#        funding_rounds  founded_year          seed       venture  \
# count    1.200000e+04  1.200000e+04  1.200000e+04  1.200000e+04
# mean     3.541971e-13  4.195423e-10  3.085236e-08  1.662351e-06
# std      1.334125e-12  1.495255e-09  2.960983e-07  1.035451e-05
# min      4.452081e-15  8.832929e-12  0.000000e+00  0.000000e+00
# 25%      2.947016e-14  4.201756e-11  0.000000e+00  0.000000e+00
# 50%      1.032218e-13  1.410033e-10  0.000000e+00  2.947016e-08
# 75%      2.765491e-13  3.336890e-10  0.000000e+00  5.931662e-07
# max      5.197149e-11  3.482090e-08  1.732892e-05  6.369745e-04
#
#        equity_crowdfunding   undisclosed  convertible_note  debt_financing  \
# count         1.200000e+04  1.200000e+04      1.200000e+04    1.200000e+04
# mean          6.143260e-10  8.164709e-09      1.280209e-09    2.022084e-07
# std           2.970262e-08  2.823400e-07      3.069487e-08    4.127700e-06
# min           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 25%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 50%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 75%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# max           2.707893e-06  2.731959e-05      1.604066e-06    2.959108e-04
#
#               angel         grant  ...  econ_disadvantaged_math_test_valid  \
# count  1.200000e+04  1.200000e+04  ...                        1.200000e+04
# mean   1.074941e-08  1.650022e-08  ...                        3.796013e-10
# std    1.703785e-07  8.367998e-07  ...                        2.016380e-10
# min    0.000000e+00  0.000000e+00  ...                        2.058561e-11
# 25%    0.000000e+00  0.000000e+00  ...                        3.160619e-10
# 50%    0.000000e+00  0.000000e+00  ...                        3.597043e-10
# 75%    0.000000e+00  0.000000e+00  ...                        4.079363e-10
# max    1.546796e-05  7.238729e-05  ...                        5.693234e-09
#
#        foster_care_read_test_valid  foster_care_math_test_valid  \
# count                 1.200000e+04                 1.200000e+04
# mean                  3.396243e-12                 3.427589e-12
# std                   2.205557e-12                 2.212648e-12
# min                   0.000000e+00                 0.000000e+00
# 25%                   2.493939e-12                 2.412134e-12
# 50%                   3.307610e-12                 3.436648e-12
# 75%                   3.890061e-12                 3.919531e-12
# max                   5.287834e-11                 5.287834e-11
#
#        military_connected_read_test_valid  military_connected_math_test_valid  \
# count                        1.200000e+04                        1.200000e+04
# mean                         8.308768e-12                        8.281442e-12
# std                          9.007006e-12                        9.070898e-12
# min                          0.000000e+00                        0.000000e+00
# 25%                          3.059423e-12                        3.059423e-12
# 50%                          7.735508e-12                        7.912323e-12
# 75%                          1.128507e-11                        1.125537e-11
# max                          3.163946e-10                        3.163946e-10
#
#          population     nTeachers    enrollment  nPublicSchools      nSchools
# count  1.200000e+04  1.200000e+04  1.200000e+04    1.200000e+04  1.200000e+04
# mean   1.483362e-09  3.408101e-11  1.404307e-09    2.403857e-12  2.457378e-12
# std    6.697241e-10  2.489762e-10  6.310044e-10    6.705633e-13  6.544017e-13
# min   -6.584196e-10 -3.287304e-09 -2.125695e-10    5.530982e-13  1.262028e-12
# 25%    1.234063e-09  5.640588e-11  1.177657e-09    2.267103e-12  2.310716e-12
# 50%    1.328670e-09  7.017850e-11  1.250201e-09    2.389421e-12  2.424804e-12
# 75%    1.673674e-09  8.719739e-11  1.582428e-09    2.485260e-12  2.518120e-12
# max    2.858810e-08  1.381068e-09  2.720703e-08    1.732383e-11  1.732383e-11
#
# [8 rows x 72 columns]

# %%
#categorical columns
df[cat_cols].describe()
cols_delete = ["homepage_url", "name", "founded_quarter", "permalink", "country_code"]
df = df.drop(cols_delete, axis = 1)

# %%
df.describe()
# Out:
#        funding_rounds  founded_year          seed       venture  \
# count    1.200000e+04  1.200000e+04  1.200000e+04  1.200000e+04
# mean     3.541971e-13  4.195423e-10  3.085236e-08  1.662351e-06
# std      1.334125e-12  1.495255e-09  2.960983e-07  1.035451e-05
# min      4.452081e-15  8.832929e-12  0.000000e+00  0.000000e+00
# 25%      2.947016e-14  4.201756e-11  0.000000e+00  0.000000e+00
# 50%      1.032218e-13  1.410033e-10  0.000000e+00  2.947016e-08
# 75%      2.765491e-13  3.336890e-10  0.000000e+00  5.931662e-07
# max      5.197149e-11  3.482090e-08  1.732892e-05  6.369745e-04
#
#        equity_crowdfunding   undisclosed  convertible_note  debt_financing  \
# count         1.200000e+04  1.200000e+04      1.200000e+04    1.200000e+04
# mean          6.143260e-10  8.164709e-09      1.280209e-09    2.022084e-07
# std           2.970262e-08  2.823400e-07      3.069487e-08    4.127700e-06
# min           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 25%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 50%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 75%           0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# max           2.707893e-06  2.731959e-05      1.604066e-06    2.959108e-04
#
#               angel         grant  ...  econ_disadvantaged_math_test_valid  \
# count  1.200000e+04  1.200000e+04  ...                        1.200000e+04
# mean   1.074941e-08  1.650022e-08  ...                        3.796013e-10
# std    1.703785e-07  8.367998e-07  ...                        2.016380e-10
# min    0.000000e+00  0.000000e+00  ...                        2.058561e-11
# 25%    0.000000e+00  0.000000e+00  ...                        3.160619e-10
# 50%    0.000000e+00  0.000000e+00  ...                        3.597043e-10
# 75%    0.000000e+00  0.000000e+00  ...                        4.079363e-10
# max    1.546796e-05  7.238729e-05  ...                        5.693234e-09
#
#        foster_care_read_test_valid  foster_care_math_test_valid  \
# count                 1.200000e+04                 1.200000e+04
# mean                  3.396243e-12                 3.427589e-12
# std                   2.205557e-12                 2.212648e-12
# min                   0.000000e+00                 0.000000e+00
# 25%                   2.493939e-12                 2.412134e-12
# 50%                   3.307610e-12                 3.436648e-12
# 75%                   3.890061e-12                 3.919531e-12
# max                   5.287834e-11                 5.287834e-11
#
#        military_connected_read_test_valid  military_connected_math_test_valid  \
# count                        1.200000e+04                        1.200000e+04
# mean                         8.308768e-12                        8.281442e-12
# std                          9.007006e-12                        9.070898e-12
# min                          0.000000e+00                        0.000000e+00
# 25%                          3.059423e-12                        3.059423e-12
# 50%                          7.735508e-12                        7.912323e-12
# 75%                          1.128507e-11                        1.125537e-11
# max                          3.163946e-10                        3.163946e-10
#
#          population     nTeachers    enrollment  nPublicSchools      nSchools
# count  1.200000e+04  1.200000e+04  1.200000e+04    1.200000e+04  1.200000e+04
# mean   1.483362e-09  3.408101e-11  1.404307e-09    2.403857e-12  2.457378e-12
# std    6.697241e-10  2.489762e-10  6.310044e-10    6.705633e-13  6.544017e-13
# min   -6.584196e-10 -3.287304e-09 -2.125695e-10    5.530982e-13  1.262028e-12
# 25%    1.234063e-09  5.640588e-11  1.177657e-09    2.267103e-12  2.310716e-12
# 50%    1.328670e-09  7.017850e-11  1.250201e-09    2.389421e-12  2.424804e-12
# 75%    1.673674e-09  8.719739e-11  1.582428e-09    2.485260e-12  2.518120e-12
# max    2.858810e-08  1.381068e-09  2.720703e-08    1.732383e-11  1.732383e-11
#
# [8 rows x 72 columns]

# %%
def drop_table(conn, name):
        existingTables=conn.execute("SHOW TABLES").fetchall()
        if(len(existingTables)>0):
            for table in existingTables:
                if(table[0] == name):
                    conn.execute("DROP TABLE " + name)
def generate_table(conn, df, name):
        drop_table(conn, name)
        existingTables=conn.execute("SHOW TABLES").fetchall()
        if(len(existingTables)>0):
            for table in existingTables:
                if(table[0] == name):
                    conn.execute("DROP TABLE " + name)
        conn.execute("CREATE TABLE " + name + " AS SELECT * FROM df")

# %%
generate_table(conn,df,"startups_studentsPerformance")
existingTables = conn.execute("SHOW TABLES").fetchall()
for t in existingTables:
    query = "SELECT * from " + t[0]
    df = conn.execute(query).fetchdf()
df.head()
# Out:
#                                        category_list                 market   \
# 0                              |Enterprise Software|    Enterprise Software
# 1                                      |Real Estate|            Real Estate
# 2                                         |Software|               Software
# 3                                   |Semiconductors|         Semiconductors
# 4  |Personal Finance|Bitcoin|Information Security...   Information Security
#
#    funding_total_usd  state_code          region          city  \
# 0           3,49,000     Unknown       Sheffield     SHEFFIELD
# 1                -            UT  Salt Lake City  SOUTH JORDAN
# 2       20,00,00,000          NY   New York City     HAWTHORNE
# 3           8,08,000     Unknown         Glasgow       GLASGOW
# 4        6,00,00,000          CA     SF Bay Area     PALO ALTO
#
#    funding_rounds  founded_at founded_month  founded_year  ...  \
# 0    3.830485e-13  2003-01-01       2003-01  7.672461e-10  ...
# 1    1.935644e-13  2014-08-21       2014-08  3.898387e-10  ...
# 2    8.238600e-14  1999-01-01       1999-01  1.646896e-10  ...
# 3    1.674167e-13     Unknown       Unknown  3.363067e-10  ...
# 4    3.325252e-13  2012-01-01       2012-01  3.345204e-10  ...
#
#   foster_care_read_test_valid foster_care_math_test_valid  \
# 0                4.596582e-12                4.596582e-12
# 1                3.677724e-12                4.258417e-12
# 2                3.789756e-12                3.954528e-12
# 3                1.841584e-12                1.674167e-12
# 4                2.493939e-12                2.327676e-12
#
#    military_connected_read_test_valid  military_connected_math_test_valid  \
# 0                        7.660969e-12                        8.810115e-12
# 1                        6.000497e-12                        6.000497e-12
# 2                        1.499425e-11                        1.499425e-11
# 3                        3.013501e-12                        3.013501e-12
# 4                        9.975756e-13                        1.163838e-12
#
#      population     nTeachers    enrollment  nPublicSchools      nSchools  \
# 0  8.875233e-10  7.086397e-11  8.166593e-10    3.447436e-12  3.447436e-12
# 1  2.510918e-09 -3.287304e-09  2.510918e-09    3.290595e-12  3.290595e-12
# 2  1.374693e-09  6.838038e-11  1.306312e-09    2.471580e-12  2.636352e-12
# 3  1.213771e-09  6.931052e-11  1.144461e-09    2.511251e-12  2.511251e-12
# 4  1.527455e-09  8.695534e-11  1.440499e-09    1.496363e-12  1.662626e-12
#
#       status
# 0  operating
# 1  operating
# 2  operating
# 3     closed
# 4  operating
#
# [5 rows x 83 columns]

# %%
conn.close()
